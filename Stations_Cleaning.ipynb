# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidSchneider47/ALIrecommendation/blob/main/Stations_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#run the code to import a file from my local directory into Google Colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d91b8e2b-8f52-451c-8194-4b87e83b3c19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d91b8e2b-8f52-451c-8194-4b87e83b3c19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#define the file as df
df= pd.read_csv('Stations.csv')

# %% [markdown]
# Exploratory Data Analysis

# %%
#display the column headings and the first few rows
df.head()
# Out:
#   NTD ID                              Agency Name  Reporter Type  \
# 0      1  King County Department of Metro Transit  Full Reporter
# 1      1  King County Department of Metro Transit  Full Reporter
# 2      1  King County Department of Metro Transit  Full Reporter
# 3      1  King County Department of Metro Transit  Full Reporter
# 4      1  King County Department of Metro Transit  Full Reporter
#
#   Reporting Module Primary Mode Served Secondary Modes Served  Facility ID  \
# 0            Urban                 Bus                    NaN      19124.0
# 1            Urban                 Bus                    NaN      19125.0
# 2            Urban                 Bus                    NaN      19126.0
# 3            Urban                 Bus                    NaN      19127.0
# 4            Urban                 Bus                    NaN      19141.0
#
#                         Facility Type                    Facility Name  \
# ...

# %%
#identify the number of rows and columns
df.shape
# Out:
# (4479, 31)

# %%
#identify the data types
# it would be good to make some data conversions in some of these items. We'll come back to this
df.dtypes
# Out:
# NTD ID                                       object
# Agency Name                                  object
# Reporter Type                                object
# Reporting Module                             object
# Primary Mode Served                          object
# Secondary Modes Served                       object
# Facility ID                                 float64
# Facility Type                                object
# Facility Name                                object
# Street Address                               object
# City                                         object
# State                                        object
# ZIP Code                                    float64
# Latitude                                    float64
# Longitude                                   float64
# Non-Agency Mode Served                       object
# Private Modes Served                         object
# Administrative/Maintenance Facility Flag    float64
# ...

# %%
#check for null values. Strange, I didn't think there were any nulls for "NTD ID" and some other categories
df.isnull().sum()
# Out:
# NTD ID                                        15
# Agency Name                                   15
# Reporter Type                                 15
# Reporting Module                              15
# Primary Mode Served                           15
# Secondary Modes Served                      3958
# Facility ID                                   15
# Facility Type                                 15
# Facility Name                                 15
# Street Address                               913
# City                                         814
# State                                        821
# ZIP Code                                     839
# Latitude                                      68
# Longitude                                     68
# Non-Agency Mode Served                      4474
# Private Modes Served                        4390
# Administrative/Maintenance Facility Flag      15
# Passenger/Parking Facility Flag               15
# ...

# %%
#identify the rows with a null value for NTD ID
filtered_rows = df[df['NTD ID'].isnull()]

# %%
#created a data frame for these rows
filtered_rows.to_csv('filtered_rows.csv')

# %%
#xported the rows for further inspection. It looks like the file picked up a few blank rows from the .csv in my local directory. OK to delte
from google.colab import files
files.download('filtered_rows.csv')

# %% [markdown]
# Eliminate Null Values

# %%
#delete the rows where "NTD_ID" is null
df = df.dropna(subset=['NTD ID'])

# %%
#check for the new data frame
df.shape
# Out:
# (4464, 31)

# %%
#check again for fields with null values. Good that "AddressComplete" has no null values
#however, it would be good to populate the missing lon/lat values and some other info. We'll come back to this
df.isnull().sum()
# Out:
# NTD ID                                         0
# Agency Name                                    0
# Reporter Type                                  0
# Reporting Module                               0
# Primary Mode Served                            0
# Secondary Modes Served                      3943
# Facility ID                                    0
# Facility Type                                  0
# Facility Name                                  0
# Street Address                               898
# City                                         799
# State                                        806
# ZIP Code                                     824
# Latitude                                      53
# Longitude                                     53
# Non-Agency Mode Served                      4459
# Private Modes Served                        4375
# Administrative/Maintenance Facility Flag       0
# Passenger/Parking Facility Flag                0
# ...

# %% [markdown]
# Address Duplicate Data

# %%
#check the dataframe for entire row duplicates. Lpoks iike no entirely duplicated rows
df.duplicated().sum()
# Out:
# 0

# %%
#check to see if there are any stations with the exact same lon/lat coordinates
duplicates = df[df.duplicated(subset=['Longitude', 'Latitude'], keep=False)]

# %%
#convert these to a .csv
duplicates.to_csv('duplicates.csv')

# %%
#identify the number of rows that include duplicates.
# assuming one duplicate row per original row, that's 399 duplicate rows to drop.
duplicates.shape
# Out:
# (797, 31)

# %%
#download the file for a closer inspection
#offline inspection reveals that some transit stations are served by multiple modes
#we will consider the heavy rail, light rail, and streetcar rail modes to be the primary modes in these cases.
files.download('duplicates.csv')

# %%
# Identify rows where 'Primary Mode Served' contains one of the specified terms
specified_terms = ['Bus', 'Commuter Bus', 'Maglev', 'Streetcar Rail']
filtered_rows = df[df['Primary Mode Served'].isin(specified_terms)]

# %%
# Drop the duplicates from the dataset based on the terms specified in 'Primary Mode Served'
df = df.drop(filtered_rows.index)

# Show the shape of the original and new DataFrame for comparison
original_shape = df.shape
new_shape = df.shape

original_shape, new_shape
# Out:
# ((3698, 31), (3698, 31))

# %%
#check again to see if there are any stations with the exact same lon/lat coordinates
duplicates = df[df.duplicated(subset=['Longitude', 'Latitude'], keep=False)]

# %%
#now we are down to 341 duplicates from 797
duplicates.shape
# Out:
# (341, 31)

# %%
#and the dataset is down to 3,698 unique rows
df.shape
# Out:
# (3698, 31)

# %%
#another source of duplicates is that there are northbound and southbound sides of the same station labeled with different facility ide
# Initialize an empty DataFrame to store rows where differences in 'Facility ID' are found
differences_facility_id_df = pd.DataFrame()
# Identify rows with duplicate 'Latitude' and 'Longitude'
duplicates = df[df.duplicated(subset=['Latitude', 'Longitude'], keep=False)].sort_values(by=['Latitude', 'Longitude'])
# Group by 'Latitude' and 'Longitude' and iterate through each group to find differences in 'Facility ID'
for _, group in duplicates.groupby(['Latitude', 'Longitude']):
    # Take the first row's 'Facility ID' as reference
    reference_facility_id = group.iloc[0]['Facility ID']
    # Iterate through each row to find differences in 'Facility ID' with the reference row
    for index, row in group.iloc[1:].iterrows():
        # Check if 'Facility ID' is different
        if row['Facility ID'] != reference_facility_id:
            # Add the index of the row to the 'differences_facility_id_df'
            differences_facility_id_df = differences_facility_id_df.append(
                {'Index': index, 'Different Facility ID': row['Facility ID']}, ignore_index=True
            )
# Out:
# <ipython-input-38-22d73dee7251>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   differences_facility_id_df = differences_facility_id_df.append(
# <ipython-input-38-22d73dee7251>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   differences_facility_id_df = differences_facility_id_df.append(
# <ipython-input-38-22d73dee7251>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   differences_facility_id_df = differences_facility_id_df.append(
# <ipython-input-38-22d73dee7251>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   differences_facility_id_df = differences_facility_id_df.append(
# ...

# %%
# Drop one of the duplicate rows where 'Facility ID' is different
# We'll drop the first occurrence and keep the subsequent ones
df = df.drop(differences_facility_id_df['Index'].astype(int))

# %%
#check the resulting data frame to see fewer rows overall
df.shape
# Out:
# (3542, 31)

# %%
#check to see if there are any stations with the exact same lon/lat coordinates
duplicates = df[df.duplicated(subset=['Longitude', 'Latitude'], keep=False)]

# %%
#now we are down to only 53 duplicates and these happen to be the 53 rows with blank lon/lat coordinates that we will fix later.
duplicates.shape
# Out:
# (53, 31)

# %%
df.isnull().sum()
# Out:
# NTD ID                                         0
# Agency Name                                    0
# Reporter Type                                  0
# Reporting Module                               0
# Primary Mode Served                            0
# Secondary Modes Served                      3078
# Facility ID                                    0
# Facility Type                                  0
# Facility Name                                  0
# Street Address                               728
# City                                         722
# State                                        726
# ZIP Code                                     722
# Latitude                                      53
# Longitude                                     53
# Non-Agency Mode Served                      3537
# Private Modes Served                        3469
# Administrative/Maintenance Facility Flag       0
# Passenger/Parking Facility Flag                0
# ...

# %%
#download the resulting file for further inspection
df.to_csv("stations_clean.csv")

# %%
files.download("stations_clean.csv")

# %% [markdown]
# Populate Missing City, State, and ZIP Code data from the AddressComplete Column

# %%
#run a complex code to populate most of the blank city, state, zip code cells from the "AddressComplete" data
import re

# Define function to extract city, state and zip from AddressComplete column
def extract_info(address):
    # Regular expression patterns to extract city, state and zip
    city_pattern = r"(?<=, )([^,]+)(?=, [A-Z]{2},)"
    state_pattern = r", ([A-Z]{2}),"
    zip_pattern = r"(\d{5})$"

    city = re.search(city_pattern, address)
    state = re.search(state_pattern, address)
    zip_code = re.search(zip_pattern, address)

    return city.group(0) if city else None, state.group(1) if state else None, zip_code.group(0) if zip_code else None

# Apply the function to extract city, state and zip
df["ExtractedCity"], df["ExtractedState"], df["ExtractedZip"] = zip(*df["AddressComplete"].apply(extract_info))

# If City, State, or Zip Code columns are empty, fill them with the extracted values
df["City"] = df["City"].where(df["City"].notnull(), df["ExtractedCity"])
df["State"] = df["State"].where(df["State"].notnull(), df["ExtractedState"])
df["ZIP Code"] = df["ZIP Code"].where(df["ZIP Code"].notnull(), df["ExtractedZip"])

# Drop the temporary extracted columns
df = df.drop(columns=["ExtractedCity", "ExtractedState", "ExtractedZip"])

# Display the updated dataframe
df[["AddressComplete", "City", "State", "ZIP Code"]].head()
# Out:
#                                       AddressComplete      City State ZIP Code
# 17         2599 N Interstate Ave, Portland, OR, 97227  Portland    OR  97227.0
# 18            Sw 5Th & Jefferson, Portland, OR, 97204  Portland    OR  97204.0
# 19  Ne Holladay St/Martin Luther King Jr Blvd, Por...  Portland    OR  97232.0
# 20        E Burnside & 102Nd Ave, Portland, OR, 97216  Portland    OR  97216.0
# 26     Sw Morrison St & 10Th Ave, Portland, OR, 97205  Portland    OR  97205.0

# %%
#test to see if there are some missing information--it looks like there are still 722 zip codesl missing
df.isnull().sum()
# Out:
# NTD ID                                         0
# Agency Name                                    0
# Reporter Type                                  0
# Reporting Module                               0
# Primary Mode Served                            0
# Secondary Modes Served                      3078
# Facility ID                                    0
# Facility Type                                  0
# Facility Name                                  0
# Street Address                               728
# City                                           0
# State                                          0
# ZIP Code                                     722
# Latitude                                      53
# Longitude                                     53
# Non-Agency Mode Served                      3537
# Private Modes Served                        3469
# Administrative/Maintenance Facility Flag       0
# Passenger/Parking Facility Flag                0
# ...

# %%
#download the resulting file for further inspection
df.to_csv("stations_clean1.csv")

# %%
files.download("stations_clean1.csv")

# %%
#run additional code to extract additional city, state, zip informatiion from the Reverse Address Column
# Redefine the function to extract city, state and zip
def extract_info(address):
    # Regular expression patterns to extract city, state and zip
    city_pattern = r"(?<=, )([^,]+)(?=, [A-Z]{2},)"
    state_pattern = r", ([A-Z]{2}),"
    zip_pattern = r"(\d{5})$"

    city = re.search(city_pattern, str(address))
    state = re.search(state_pattern, str(address))
    zip_code = re.search(zip_pattern, str(address))

    return city.group(0) if city else None, state.group(1) if state else None, zip_code.group(0) if zip_code else None

# Extract city, state, and zip from ReverseAddress column for rows with missing values
rows_with_missing_values = df[df["City"].isnull() | df["State"].isnull() | df["ZIP Code"].isnull()]

# Apply the extraction function to these rows
rows_with_missing_values[["City", "State", "ZIP Code"]] = rows_with_missing_values["ReverseAddress"].apply(extract_info).apply(pd.Series)

# Update the original dataframe
df.update(rows_with_missing_values)

# Display the updated dataframe with previously missing values
df[["ReverseAddress", "City", "State", "ZIP Code"]].head()
# Out:
# <ipython-input-46-1983709f9796>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rows_with_missing_values[["City", "State", "ZIP Code"]] = rows_with_missing_values["ReverseAddress"].apply(extract_info).apply(pd.Series)
#    ReverseAddress      City State ZIP Code
# 17            NaN  Portland    OR  97227.0
# 18            NaN  Portland    OR  97204.0
# 19            NaN  Portland    OR  97232.0
# 20            NaN  Portland    OR  97216.0
# 26            NaN  Portland    OR  97205.0

# %%
#It looks like this code has not worked
df.isnull().sum()
# Out:
# NTD ID                                         0
# Agency Name                                    0
# Reporter Type                                  0
# Reporting Module                               0
# Primary Mode Served                            0
# Secondary Modes Served                      3078
# Facility ID                                    0
# Facility Type                                  0
# Facility Name                                  0
# Street Address                               728
# City                                           0
# State                                          0
# ZIP Code                                     722
# Latitude                                      53
# Longitude                                     53
# Non-Agency Mode Served                      3537
# Private Modes Served                        3469
# Administrative/Maintenance Facility Flag       0
# Passenger/Parking Facility Flag                0
# ...

# %%
# Inspect the rows with blank ZIP Codes
blank_zip_codes = df[df["ZIP Code"].isnull()]

blank_zip_codes[["AddressComplete", "ReverseAddress", "City", "State", "ZIP Code"]]
# Out:
#      AddressComplete                                     ReverseAddress City  \
# 1634  NA, NA, NA, NA               2274 31st St, Astoria, NY 11105, USA   NA
# 1635  NA, NA, NA, NA             9022 Hoyt Ave S, Queens, NY 11102, USA   NA
# 1636  NA, NA, NA, NA             30 Av, 30th Ave, Queens, NY 11102, USA   NA
# 1637  NA, NA, NA, NA                    Broadway, Queens, NY 11106, USA   NA
# 1638  NA, NA, NA, NA                 31 St/36 Av, Queens, NY 11106, USA   NA
# ...              ...                                                ...  ...
# 2535  NA, NA, NA, NA       Parkview Station, Upper Darby, PA 19082, USA   NA
# 2536  NA, NA, NA, NA  Township Line Road Station, Haverford Township...   NA
# 2537  NA, NA, NA, NA     26-64 Crest Terrace, Norristown, PA 19401, USA   NA
# 2538  NA, NA, NA, NA  69th Street Transportation Center, 6901 Market...   NA
# 3145  NA, NA, NA, NA          Gary/Chicago Airport, Gary, IN 46406, USA   NA
#
#      State ZIP Code
# 1634    NA     None
# ...

# %%
# Define a function to extract ZIP code from a given address string
def extract_zip_from_address(address):
    zip_pattern = r"(\d{5})$"
    zip_code = re.search(zip_pattern, str(address))
    return zip_code.group(0) if zip_code else None

# For rows with blank ZIP codes, try extracting ZIP code from AddressComplete and then from ReverseAddress
blank_zip_codes["ZIP Code"] = blank_zip_codes["AddressComplete"].apply(extract_zip_from_address).fillna(
    blank_zip_codes["ReverseAddress"].apply(extract_zip_from_address))

# Update the original dataframe
df.update(blank_zip_codes)

# Check if there are still any blank ZIP Codes after the update
remaining_blank_zip_codes = df[df["ZIP Code"].isnull()]

remaining_blank_zip_codes[["AddressComplete", "ReverseAddress", "City", "State", "ZIP Code"]]
# Out:
# <ipython-input-49-f9e988bca696>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   blank_zip_codes["ZIP Code"] = blank_zip_codes["AddressComplete"].apply(extract_zip_from_address).fillna(
#      AddressComplete                                     ReverseAddress City  \
# 1634  NA, NA, NA, NA               2274 31st St, Astoria, NY 11105, USA   NA
# 1635  NA, NA, NA, NA             9022 Hoyt Ave S, Queens, NY 11102, USA   NA
# 1636  NA, NA, NA, NA             30 Av, 30th Ave, Queens, NY 11102, USA   NA
# 1637  NA, NA, NA, NA                    Broadway, Queens, NY 11106, USA   NA
# 1638  NA, NA, NA, NA                 31 St/36 Av, Queens, NY 11106, USA   NA
# ...              ...                                                ...  ...
# ...

# %%
# Display a sample of addresses from rows with missing ZIP codes
sample_addresses = remaining_blank_zip_codes[["AddressComplete", "ReverseAddress"]].sample(20)
sample_addresses
# Out:
#      AddressComplete                                     ReverseAddress
# 2072  NA, NA, NA, NA     W 116 St/Malcolm X Bl, New York, NY 10026, USA
# 1852  NA, NA, NA, NA  2937 Frederick Douglass Blvd, New York, NY 100...
# 2057  NA, NA, NA, NA            1978 Birchall Ave, Bronx, NY 10462, USA
# 1695  NA, NA, NA, NA        55 Street, 55th St, Brooklyn, NY 11219, USA
# 1725  NA, NA, NA, NA             1955 Broadway, Brooklyn, NY 11207, USA
# 1668  NA, NA, NA, NA              5907 4th Ave, Brooklyn, NY 11220, USA
# 1688  NA, NA, NA, NA            Brighton Beach, Brooklyn, NY 11235, USA
# 1803  NA, NA, NA, NA              45 Church St, New York, NY 10007, USA
# 1907  NA, NA, NA, NA    875 3rd Ave 23rd Floor, New York, NY 10022, USA
# 2101  NA, NA, NA, NA       E 42 St/Madison Ave, New York, NY 10165, USA
# 1829  NA, NA, NA, NA       Aqueduct-N Conduit Av, Queens, NY 11417, USA
# 1715  NA, NA, NA, NA                      104 St, Queens, NY 11418, USA
# ...

# %%
# Extract ZIP codes from the ReverseAddress column for the remaining rows
remaining_blank_zip_codes["ZIP Code"] = remaining_blank_zip_codes["ReverseAddress"].apply(extract_zip_from_address)

# Update the original dataframe
df.update(remaining_blank_zip_codes)

# Check again if there are still any blank ZIP Codes after the update
final_remaining_blank_zip_codes = df[df["ZIP Code"].isnull()]

final_remaining_blank_zip_codes[["AddressComplete", "ReverseAddress", "City", "State", "ZIP Code"]]
# Out:
# <ipython-input-51-6636347a1baf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   remaining_blank_zip_codes["ZIP Code"] = remaining_blank_zip_codes["ReverseAddress"].apply(extract_zip_from_address)
#      AddressComplete                                     ReverseAddress City  \
# 1634  NA, NA, NA, NA               2274 31st St, Astoria, NY 11105, USA   NA
# 1635  NA, NA, NA, NA             9022 Hoyt Ave S, Queens, NY 11102, USA   NA
# 1636  NA, NA, NA, NA             30 Av, 30th Ave, Queens, NY 11102, USA   NA
# 1637  NA, NA, NA, NA                    Broadway, Queens, NY 11106, USA   NA
# 1638  NA, NA, NA, NA                 31 St/36 Av, Queens, NY 11106, USA   NA
# ...

# %%
# Redefine the ZIP code extraction function to be more flexible
def flexible_extract_zip_from_address(address):
    zip_pattern = r"(\d{5})"
    zip_code = re.search(zip_pattern, str(address))
    return zip_code.group(0) if zip_code else None

# Directly update the ZIP Code column for the rows with missing ZIP codes using the more flexible method
df.loc[remaining_blank_zip_codes.index, "ZIP Code"] = remaining_blank_zip_codes["ReverseAddress"].apply(flexible_extract_zip_from_address)

# Check again if there are still any blank ZIP Codes after the update
final_remaining_blank_zip_codes = df[df["ZIP Code"].isnull()]

final_remaining_blank_zip_codes[["AddressComplete", "ReverseAddress", "City", "State", "ZIP Code"]]
# Out:
#      AddressComplete                                  ReverseAddress  \
# 1776  NA, NA, NA, NA          Broadway/Dyckman St, New York, NY, USA
# 1846  NA, NA, NA, NA        Grand Concourse/E 182 St, Bronx, NY, USA
# 1928  NA, NA, NA, NA            Broadway/w 225 St, New York, NY, USA
# 2004  NA, NA, NA, NA                     Longwood Av, Bronx, NY, USA
# 2010  NA, NA, NA, NA                        Woodlawn, Bronx, NY, USA
# 2043  NA, NA, NA, NA  Brooklyn Bridge - City Hall, New York, NY, USA
# 2070  NA, NA, NA, NA        W 135 St/Malcolm X Bl, New York, NY, USA
# 2502  NA, NA, NA, NA     Girard Av & Broad St, Philadelphia, PA, USA
# 2521  NA, NA, NA, NA           8th and Market, Philadelphia, PA, USA
#
#               City State ZIP Code
# 1776      New York    NY     None
# 1846         Bronx    NY     None
# 1928      New York    NY     None
# 2004         Bronx    NY     None
# 2010         Bronx    NY     None
# 2043      New York    NY     None
# ...

# %%
#now we are down to a more manageable 9 records with no zip codes!
df.isnull().sum()
# Out:
# NTD ID                                         0
# Agency Name                                    0
# Reporter Type                                  0
# Reporting Module                               0
# Primary Mode Served                            0
# Secondary Modes Served                      3078
# Facility ID                                    0
# Facility Type                                  0
# Facility Name                                  0
# Street Address                               728
# City                                           0
# State                                          0
# ZIP Code                                       9
# Latitude                                      53
# Longitude                                     53
# Non-Agency Mode Served                      3537
# Private Modes Served                        3469
# Administrative/Maintenance Facility Flag       0
# Passenger/Parking Facility Flag                0
# ...

# %%
#download the file for further inspection
df.to_csv("stations_clean2.csv")

# %%
#download the file for further inspection
files.download("stations_clean2.csv")

# %% [markdown]
# Populate Missing Lon/Lat Data

# %%
#Now let's see if we can find lon/lat coordinates for the 53 rows with missing coordiantes but an addressing
# !pip install googlemaps
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40713 sha256=3b576a2c00150cae19429d8e6d49005b9c236618638fdd957318a31c62e783ba
#   Stored in directory: /root/.cache/pip/wheels/17/f8/79/999d5d37118fd35d7219ef57933eb9d09886c4c4503a800f84
# Successfully built googlemaps
# ...

# %%
import googlemaps

# %%
def geocode_addresses(api_key, addresses):
    gmaps = googlemaps.Client(key=api_key)
    lat_lon_results = {}

    for address in addresses:
        result = gmaps.geocode(address)
        if result and len(result) > 0:
            location = result[0]['geometry']['location']
            lat_lon_results[address] = (location['lat'], location['lng'])
        else:
            lat_lon_results[address] = (None, None)

    return lat_lon_results

# %%
api_key="AIzaSyBnqCaL5Nn8hGkDfgwDIwMUjsirRG-18L0"

# %%
"#Let's drop some fields that we are not going to use from the dataset.
df = df.drop(['Secondary Modes Served', 'Street Address','Non-Agency Mode Served','Private Modes Served','Number of Parking Spaces','Notes'], axis=1)

# %%
addresses_to_geocode = ["Sw 5Th & Jefferson, Portland, OR, 97204",
    "Sw 18Th Ave & Jefferson St, Portland, OR, 97201",
    "Nw 5Th & Couch, Portland, OR, 97209",
    "Sw 5Th & Jackson, Portland, OR, 97201",
    "Sw 6Th & College, Portland, OR, 97201",
    "Sw 5Th & Mill, Portland, OR, 97201",
    "Sw 6Th & Montgomery, Portland, OR, 97201",
    "Sw 5Th & Oak, Portland, OR, 97204",
    "Sw 6Th & Madison, Portland, OR, 97204",
    "Sw 6Th & Pine, Portland, OR, 97204",
    "Nw 5Th & Glisan, Portland, OR, 97209",
    "Sw 18Th Ave & Salmon St, Portland, OR, 97205",
    "Main St. & Atlantic Ave., Matawan, NJ, 07747",
    "Railroad Plz Shore Rd. & Ohio Ave., Absecon, NJ, 08205",
    "Main St. & Corlies Ave., Allenhurst, NJ, 07711",
    "Bay & Pine St., Montclair, NJ, 07042",
    "Main St. & Rt. 202, Boonton, NJ, 07005",
    "S. Harrison Ave & Prospect St., East Orange, NJ, 07018",
    "East Main St. & Cole Drive, Bridgewater, NJ, 08807",
    "Front St. Between Fairmount & Washington Ave., Chatham, NJ, 07928",
    "Valley Rd. & Long Hill Rd., Gillette, NJ, 07933",
    "Broadway & Hillsdale Ave., Hillsdale, NJ, 07642",
    "Brookside Ave. & 1St St., Ho-Ho-Kus, NJ, 07450",
    "Main St. & Comly Rd., Lincoln Park, NJ, 07035",
    "3Rd Ave. Between North Bath Ave. & Morris Ave., Long Branch, NJ, 07740",
    "Main Street & Woodbridge Ave, Metuchen, NJ, 08837",
    "Division Ave. Between Oaks Rd. & Valley Rd., Millington, NJ, 07946",
    "Rt. 80 & Howard Blvd, Mt. Arlington, NJ, 07856",
    "Station Rd & Rt. 53, Denville, NJ, 07834",
    "Main St. & Rt. 46, Netcong, NJ, 07857",
    "25 University Ave (Broad St. & University Pl), Newark, NJ, 07102",
    "Elm St. Between Smith St. & Market St., Perth Amboy, NJ, 08861",
    "County Rd & County Ave, Secaucus, NJ, 07094",
    "S. Bridge & Veterans Memorial Dr. W, Somerville, NJ, 08876",
    "Central Ave. & Main St., Stirling, NJ, 07980",
    "Prospect & Hewson Aves., Waldwick, NJ, 07463",
    "Broadway & Westwood Ave., Westwood, NJ, 07675",
    "Broadway & Woodcliff Ave., Woodcliff, NJ, 07677",
    "34Th & Ave E, Bayonne, NJ, 07002",
    "45Th & Ave E, Bayonne, NJ, 07002",
    "Between Hudson & Greene St., Jersey City, NJ, 07302",
    "East Of Greene St. Between Morgan & Steuben Sts., Jersey City, NJ, 07302"]

# %%
# Get geocoded results
results = geocode_addresses(api_key, addresses_to_geocode)

# %%
# Populate the DataFrame
for index, row in df.iterrows():
    if pd.isnull(row['Latitude']) and pd.isnull(row['Longitude']):
        address = row['AddressComplete']
        if address in results:
            lat, lon = results[address]
            df.at[index, 'Latitude'] = lat
            df.at[index, 'Longitude'] = lon

# %%
#let's re-check for missing lons and lats. None!
df.isnull().sum()
# Out:
# NTD ID                                         0
# Agency Name                                    0
# Reporter Type                                  0
# Reporting Module                               0
# Primary Mode Served                            0
# Secondary Modes Served                      3078
# Facility ID                                    0
# Facility Type                                  0
# Facility Name                                  0
# Street Address                               728
# City                                           0
# State                                          0
# ZIP Code                                       9
# Latitude                                       0
# Longitude                                      0
# Non-Agency Mode Served                      3537
# Private Modes Served                        3469
# Administrative/Maintenance Facility Flag       0
# Passenger/Parking Facility Flag                0
# ...

# %% [markdown]
# Convert a few datatypes into Objects

# %%
#Lets check the resulting structure
df.shape
# Out:
# (3542, 31)

# %%
#now most of the columns in thr dataset have no missing values
df.isnull().sum()
# Out:
# NTD ID                                         0
# Agency Name                                    0
# Reporter Type                                  0
# Reporting Module                               0
# Primary Mode Served                            0
# Secondary Modes Served                      3078
# Facility ID                                    0
# Facility Type                                  0
# Facility Name                                  0
# Street Address                               728
# City                                           0
# State                                          0
# ZIP Code                                       9
# Latitude                                       0
# Longitude                                      0
# Non-Agency Mode Served                      3537
# Private Modes Served                        3469
# Administrative/Maintenance Facility Flag       0
# Passenger/Parking Facility Flag                0
# ...

# %%
#convert zip code from a float to an object
df['ZIP Code'] = df['ZIP Code'].astype('str')

# %%
#convert Year Built from a float to an object
df['Year Built or Reconstructed as New'] = df['Year Built or Reconstructed as New'].astype('str')

# %%
#check the results
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3542 entries, 17 to 4463
# Data columns (total 31 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   NTD ID                                    3542 non-null   object
#  1   Agency Name                               3542 non-null   object
#  2   Reporter Type                             3542 non-null   object
#  3   Reporting Module                          3542 non-null   object
#  4   Primary Mode Served                       3542 non-null   object
#  5   Secondary Modes Served                    464 non-null    object
#  6   Facility ID                               3542 non-null   float64
#  7   Facility Type                             3542 non-null   object
#  8   Facility Name                             3542 non-null   object
#  9   Street Address                            2814 non-null   object
# ...

# %% [markdown]
# Perform Some Remaining Cleanup Activities

# %%
#Replace values of NYC Boroughs to the NYC as a Whole.
# List of values to replace
replace_values = ["Bronx", "Queens", "Brooklyn", "Staten Island"]

# Replace those values with "New York, NY"
df['City'] = df['City'].replace(replace_values, "New York, NY")

# %%
#Update the zipcodes with less than five digits by adding leading zeroes.
df['ZIP Code'] = df['ZIP Code'].apply(lambda x: x.zfill(5))

# %%
#drop columns we will not be using
df.drop(['Secondary Modes Served','Street Address','Non-Agency Mode Served','Private Modes Served','Number of Parking Spaces','Notes'],axis=1, inplace=True)

# %%
# Create a new column 'Final Address' that contains the merged information from AddressComplete and ReverseAddress
df['Final Address'] = df.apply(
    lambda row: row['ReverseAddress'] if row['AddressComplete'] == "NA, NA, NA, NA" else row['AddressComplete'],
    axis=1
)

# %% [markdown]
# Print out the final cleaned data product

# %%
#download the file for further inspection
df.to_csv("stations_clean_final.csv")

# %%
#download the file for further inspection
files.download("stations_clean_final.csv")
